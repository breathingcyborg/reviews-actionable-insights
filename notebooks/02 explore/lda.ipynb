# %%
# !pip install nltk
# !pip install --upgrade gensim 
# !pip install keybert[all]
# !pip install yake
# !pip install pyldavis
# !pip install numexpr

# %%
import requests
import time
import random
from bs4 import BeautifulSoup
import re
from datetime import datetime
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import random
import nltk
from nltk.stem import PorterStemmer, SnowballStemmer, WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
from keybert import KeyBERT
import string
from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel
import pyLDAvis
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
pyLDAvis.enable_notebook()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def parse_reviews(page_html):
  reviews = []
  page_html = BeautifulSoup(page_html)
  review_divs = page_html.find_all(id=re.compile("customer_review.*"))
  for div in review_divs:
    name = div.find(class_=re.compile(r'.*profile-name.*')).text.strip()
    title = div.find("a", class_=re.compile(r'.*review-title.*')).text.strip()
    text = div.find(class_=re.compile(r"review-text-content")).find("span").text.strip()
    
    rating = div.find(title=re.compile(r"\d+\.?\d? out of \d stars")).text.strip()
    rating, out_of = re.findall(r"(\d+\.?\d?).*(\d+\.?\d?)", rating)[0]
    rating = float(rating)
    out_of = float(out_of)
    
    review_date = div.find(class_=r'review-date').text.strip()
    review_date = re.findall(r'\d{1,2}.*\d{4}', review_date)[0]
    review_date = datetime.strptime(review_date, '%d %B %Y').date()

    review = dict(
        name=name,
        title=title,
        review=text,
        rating=rating,
        rating_out_of=out_of,
        date=review_date,
    )
    reviews.append(review)
  return reviews

def scrape_reviews(url, start_page=1, end_page=2, wait_time=10):
  reviews = []
  for page in range(start_page, end_page+1):
    page_url = f"{url}&pageNumber={page}&sortBy=recent"
    response = requests.get(page_url)
    page_reviews = parse_reviews(response.text)
    reviews.extend(page_reviews)
  time.sleep(random.randint(1, wait_time))
  return reviews

# %%
url = "https://www.amazon.in/SeCro-USB-Audio-Sound-Card/product-reviews/B07WSBKPXX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

start_page = 1
end_page = 30
wait_time = 10

reviews = scrape_reviews(url, 
                         start_page=start_page, 
                         end_page=end_page, 
                         wait_time=wait_time)

# %%
reviews = list(pd.read_csv('./reviews.csv').T.to_dict().values())

# %%
pd.DataFrame(reviews).to_csv("reviews.csv", index=False)

# %%
pd.read_csv("./reviews.csv")
# Out:
#                name  ...        date
# 0              Hema  ...  2021-11-09
# 1      Mahesh kumar  ...  2021-11-07
# 2       amey ghatge  ...  2021-10-09
# 3    Lobzang Dorjay  ...  2021-09-04
# 4    Kaustubh bhoir  ...  2021-09-01
# ..              ...  ...         ...
# 144       R.S.Robin  ...  2019-11-25
# 145        Rahul pa  ...  2019-11-24
# 146      Madhu Bala  ...  2019-11-22
# 147  Rajat Khanduri  ...  2019-11-11
# 148   VAIBHAV DOSHI  ...  2019-11-10
#
# [149 rows x 6 columns]

# %% [markdown]
# # Just Simple TF-IDF

# %%
def pos_filter(tokens):
  tagged = nltk.pos_tag(tokens)
  return [
    word for word, pos in tagged 
    if len(pos) >= 2 and pos[:2] in ['NN', 'JJ', 'IN', 'RB']
  ]
  # print(pos)
  # raise Exception("asdf")
  # return len(pos) > 2 and pos[:2] in ['NN', 'JJ', 'IN']

def tfidf_preprocess(texts):
  texts = [text.lower() for text in texts] # lower
  texts = [word_tokenize(t.replace(".", " ")) for t in texts] # tokenize
  texts = [[word for word in t if word not in string.punctuation] for t in texts] # remove punc
  # texts = [pos_filter(t) for t in texts] # filter pos
  return texts

reviews_texts = tfidf_preprocess([r['review'] for r in reviews])
# remove puncuations
# preprocess [just nowns and adjectives]
# lemmatize

# %%
[r['review'] for r in reviews[:10]]
# Out:
# ['It was not good.. For earphones  connection it was not working correctly',
#  'Jaldi kharab ho gaya',
#  'Within one month this product has stopped working. Does anyone from company read this? Let me know how to replace or return this product?',
#  'Sound quality is just great if we use earphones a d headphones.',
#  'Very nice long cable with USB ports not to waste money for usb ports very nice loved it I recommend to buy this',
#  'Super dislike it. Will never take if for free aslo',
#  "It's Amazing...",
#  'This is not much better than the DAC on my laptop.The major issue is it keeps getting disconnected randomly and frequently from the laptop USB port.I have nothing plugged into the USB ports on the device and it just keeps happening. The AUX port on device works well.otherwise the packing and shipping had no issues. Device has a green LED to tell you its switched on.',
#  'Ok',
#  'Audio port not working, usb port only working. Very bad, Sound port not working, mice port not working, only usb working.']

# %%
reviews_texts[:10]
# Out:
# [['it',
#   'was',
#   'not',
#   'good',
#   'for',
#   'earphones',
#   'connection',
#   'it',
#   'was',
#   'not',
#   'working',
#   'correctly'],
#  ['jaldi', 'kharab', 'ho', 'gaya'],
#  ['within',
#   'one',
#   'month',
#   'this',
#   'product',
#   'has',
#   'stopped',
#   'working',
#   'does',
#   'anyone',
#   'from',
#   'company',
#   'read',
#   'this',
#   'let',
#   'me',
#   'know',
#   'how',
#   'to',
#   'replace',
#   'or',
#   'return',
#   'this',
#   'product'],
#  ['sound',
#   'quality',
#   'is',
#   'just',
#   'great',
#   'if',
#   'we',
#   'use',
#   'earphones',
#   'a',
#   'd',
#   'headphones'],
#  ['very',
#   'nice',
#   'long',
#   'cable',
#   'with',
#   'usb',
#   'ports',
#   'not',
#   'to',
#   'waste',
#   'money',
#   'for',
#   'usb',
#   'ports',
#   'very',
#   'nice',
#   'loved',
#   'it',
#   'i',
#   'recommend',
#   'to',
#   'buy',
#   'this'],
#  ['super',
#   'dislike',
#   'it',
#   'will',
#   'never',
#   'take',
#   'if',
#   'for',
#   'free',
#   'aslo'],
#  ['it', "'s", 'amazing'],
#  ['this',
#   'is',
#   'not',
#   'much',
#   'better',
#   'than',
#   'the',
#   'dac',
#   'on',
#   'my',
#   'laptop',
#   'the',
#   'major',
#   'issue',
#   'is',
#   'it',
#   'keeps',
#   'getting',
#   'disconnected',
#   'randomly',
#   'and',
#   'frequently',
#   'from',
#   'the',
#   'laptop',
#   'usb',
#   'port',
#   'i',
#   'have',
#   'nothing',
#   'plugged',
#   'into',
#   'the',
#   'usb',
#   'ports',
#   'on',
#   'the',
#   'device',
#   'and',
#   'it',
#   'just',
#   'keeps',
#   'happening',
#   'the',
#   'aux',
#   'port',
#   'on',
#   'device',
#   'works',
#   'well',
#   'otherwise',
#   'the',
#   'packing',
#   'and',
#   'shipping',
#   'had',
#   'no',
#   'issues',
#   'device',
#   'has',
#   'a',
#   'green',
#   'led',
#   'to',
#   'tell',
#   'you',
#   'its',
#   'switched',
#   'on'],
#  ['ok'],
#  ['audio',
#   'port',
#   'not',
#   'working',
#   'usb',
#   'port',
#   'only',
#   'working',
#   'very',
#   'bad',
#   'sound',
#   'port',
#   'not',
#   'working',
#   'mice',
#   'port',
#   'not',
#   'working',
#   'only',
#   'usb',
#   'working']]

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 4))
vectorizer.fit([" ".join(r) for r in reviews_texts])
# Out:
# TfidfVectorizer(ngram_range=(2, 4))

# %%
vectorizer.vocabulary_
# Out:
# {'it was': 3496,
#  'was not': 7329,
#  'not good': 4330,
#  'good for': 2507,
#  'for earphones': 2199,
#  'earphones connection': 1947,
#  'connection it': 1532,
#  'not working': 4381,
#  'working correctly': 7758,
#  'it was not': 3497,
#  'was not good': 7330,
#  'not good for': 4333,
#  'good for earphones': 2508,
#  'for earphones connection': 2200,
#  'earphones connection it': 1948,
#  'connection it was': 1533,
#  'was not working': 7334,
#  'not working correctly': 4384,
#  'it was not good': 3498,
#  'was not good for': 7331,
#  'not good for earphones': 4334,
#  'good for earphones connection': 2509,
#  'for earphones connection it': 2201,
#  'earphones connection it was': 1949,
#  'connection it was not': 1534,
#  'it was not working': 3499,
#  'was not working correctly': 7335,
#  'jaldi kharab': 3595,
#  'kharab ho': 3669,
#  'ho gaya': 2788,
#  'jaldi kharab ho': 3596,
#  'kharab ho gaya': 3670,
#  'jaldi kharab ho gaya': 3597,
#  'within one': 7674,
#  'one month': 4614,
#  'month this': 4056,
#  'this product': 6622,
#  'product has': 5183,
#  'has stopped': 2656,
#  'stopped working': 6030,
#  'working does': 7759,
#  'does anyone': 1850,
#  'anyone from': 605,
#  'from company': 2356,
#  'company read': 1445,
#  'read this': 5479,
#  'this let': 6607,
#  'let me': 3727,
#  'me know': 3900,
#  'know how': 3675,
#  'how to': 2807,
#  'to replace': 6813,
#  'replace or': 5569,
#  'or return': 4699,
#  'return this': 5614,
#  'within one month': 7675,
#  'one month this': 4617,
#  'month this product': 4057,
#  'this product has': 6638,
#  'product has stopped': 5184,
#  'has stopped working': 2657,
#  'stopped working does': 6034,
#  'working does anyone': 7760,
#  'does anyone from': 1851,
#  'anyone from company': 606,
#  'from company read': 2357,
#  'company read this': 1446,
#  'read this let': 5480,
#  'this let me': 6608,
#  'let me know': 3728,
#  'me know how': 3901,
#  'know how to': 3676,
#  'how to replace': 2808,
#  'to replace or': 6814,
#  'replace or return': 5570,
#  'or return this': 4700,
#  'return this product': 5615,
#  'within one month this': 7676,
#  'one month this product': 4618,
#  'month this product has': 4058,
#  'this product has stopped': 6639,
#  'product has stopped working': 5185,
#  'has stopped working does': 2658,
#  'stopped working does anyone': 6035,
#  'working does anyone from': 7761,
#  'does anyone from company': 1852,
#  'anyone from company read': 607,
#  'from company read this': 2358,
#  'company read this let': 1447,
#  'read this let me': 5481,
#  'this let me know': 6609,
#  'let me know how': 3729,
#  'me know how to': 3902,
#  'know how to replace': 3677,
#  'how to replace or': 2809,
#  'to replace or return': 6815,
#  'replace or return this': 5571,
#  'or return this product': 4701,
#  'sound quality': 5946,
#  'quality is': 5394,
#  'is just': 3115,
#  'just great': 3612,
#  'great if': 2585,
#  'if we': 2878,
#  'we use': 7388,
#  'use earphones': 7076,
#  'earphones headphones': 1950,
#  'sound quality is': 5949,
#  'quality is just': 5402,
#  'is just great': 3116,
#  'just great if': 3613,
#  'great if we': 2586,
#  'if we use': 2879,
#  'we use earphones': 7389,
#  'use earphones headphones': 7077,
#  'sound quality is just': 5953,
#  'quality is just great': 5403,
#  'is just great if': 3117,
#  'just great if we': 3614,
#  'great if we use': 2587,
#  'if we use earphones': 2880,
#  'we use earphones headphones': 7390,
#  'very nice': 7240,
#  'nice long': 4251,
#  'long cable': 3789,
#  'cable with': 1276,
#  'with usb': 7666,
#  'usb ports': 7025,
#  'ports not': 5020,
#  'not to': 4359,
#  'to waste': 6862,
#  'waste money': 7363,
#  'money for': 4032,
#  'for usb': 2315,
#  'ports very': 5028,
#  'nice loved': 4254,
#  'loved it': 3835,
#  'it recommend': 3453,
#  'recommend to': 5540,
#  'to buy': 6739,
#  'buy this': 1220,
#  'very nice long': 7241,
#  'nice long cable': 4252,
#  'long cable with': 3790,
#  'cable with usb': 1277,
#  'with usb ports': 7669,
#  'usb ports not': 7031,
#  'ports not to': 5021,
#  'not to waste': 4361,
#  'to waste money': 6863,
#  'waste money for': 7366,
#  'money for usb': 4033,
#  'for usb ports': 2318,
#  'usb ports very': 7035,
#  'ports very nice': 5029,
#  'very nice loved': 7243,
#  'nice loved it': 4255,
#  'loved it recommend': 3836,
#  'it recommend to': 3454,
#  'recommend to buy': 5543,
#  'to buy this': 6745,
#  'very nice long cable': 7242,
#  'nice long cable with': 4253,
#  'long cable with usb': 3791,
#  'cable with usb ports': 1278,
#  'with usb ports not': 7670,
#  'usb ports not to': 7032,
#  'ports not to waste': 5022,
#  'not to waste money': 4362,
#  'to waste money for': 6864,
#  'waste money for usb': 7367,
#  'money for usb ports': 4034,
#  'for usb ports very': 2319,
#  'usb ports very nice': 7036,
#  'ports very nice loved': 5030,
#  'very nice loved it': 7244,
#  'nice loved it recommend': 4256,
#  'loved it recommend to': 3837,
#  'it recommend to buy': 3455,
#  'recommend to buy this': 5544,
#  'super dislike': 6077,
#  'dislike it': 1791,
#  'it will': 3504,
#  'will never': 7530,
#  'never take': 4239,
#  'take if': 6109,
#  'if for': 2861,
#  'for free': 2208,
#  'free aslo': 2343,
#  'super dislike it': 6078,
#  'dislike it will': 1792,
#  'it will never': 3507,
#  'will never take': 7531,
#  'never take if': 4240,
#  'take if for': 6110,
#  'if for free': 2862,
#  'for free aslo': 2209,
#  'super dislike it will': 6079,
#  'dislike it will never': 1793,
#  'it will never take': 3508,
#  'will never take if': 7532,
#  'never take if for': 4241,
#  'take if for free': 6111,
#  'if for free aslo': 2863,
#  'it amazing': 3304,
#  'this is': 6581,
#  'is not': 3142,
#  'not much': 4344,
#  'much better': 4111,
#  'better than': 977,
#  'than the': 6130,
#  'the dac': 6240,
#  'dac on': 1614,
#  'on my': 4565,
#  'my laptop': 4162,
#  'laptop the': 3702,
#  'the major': 6300,
#  'major issue': 3865,
#  'issue is': 3263,
#  'is it': 3112,
#  'it keeps': 3429,
#  'keeps getting': 3636,
#  'getting disconnected': 2435,
#  'disconnected randomly': 1773,
#  'randomly and': 5461,
#  'and frequently': 377,
#  'frequently from': 2347,
#  'from the': 2377,
#  'the laptop': 6283,
#  'laptop usb': 3705,
#  'usb port': 7007,
#  'port have': 4971,
#  'have nothing': 2682,
#  'nothing plugged': 4424,
#  'plugged into': 4943,
#  'into the': 3028,
#  'the usb': 6424,
#  'ports on': 5023,
#  'on the': 4572,
#  'the device': 6246,
#  'device and': 1690,
#  'and it': 409,
#  'it just': 3426,
#  'just keeps': 3615,
#  'keeps happening': 3639,
#  'happening the': 2628,
#  'the aux': 6190,
#  'aux port': 825,
#  'port on': 4987,
#  'on device': 4550,
#  'device works': 1708,
#  'works well': 7861,
#  'well otherwise': 7414,
#  'otherwise the': 4751,
#  'the packing': 6328,
#  'packing and': 4798,
#  'and shipping': 504,
#  'shipping had': 5753,
#  'had no': 2603,
#  'no issues': 4278,
#  'issues device': 3277,
#  'device has': 1696,
#  'has green': 2647,
#  'green led': 2597,
#  'led to': 3724,
#  'to tell': 6839,
#  'tell you': 6112,
#  'you its': 7973,
#  'its switched': 3562,
#  'switched on': 6093,
#  'this is not': 6590,
#  'is not much': 3148,
#  'not much better': 4345,
#  'much better than': 4112,
#  'better than the': 978,
#  'than the dac': 6131,
#  'the dac on': 6241,
#  'dac on my': 1615,
#  'on my laptop': 4570,
#  'my laptop the': 4169,
#  'laptop the major': 3703,
#  'the major issue': 6301,
#  'major issue is': 3866,
#  'issue is it': 3264,
#  'is it keeps': 3113,
#  'it keeps getting': 3430,
#  'keeps getting disconnected': 3637,
#  'getting disconnected randomly': 2436,
#  'disconnected randomly and': 1774,
#  'randomly and frequently': 5462,
#  'and frequently from': 378,
#  'frequently from the': 2348,
#  'from the laptop': 2378,
#  'the laptop usb': 6284,
#  'laptop usb port': 3706,
#  'usb port have': 7010,
#  'port have nothing': 4972,
#  'have nothing plugged': 2683,
#  'nothing plugged into': 4425,
#  'plugged into the': 4944,
#  'into the usb': 3031,
#  'the usb ports': 6437,
#  'usb ports on': 7033,
#  'ports on the': 5024,
#  'on the device': 4575,
#  'the device and': 6247,
#  'device and it': 1691,
#  'and it just': 413,
#  'it just keeps': 3427,
#  'just keeps happening': 3616,
#  'keeps happening the': 3640,
#  'happening the aux': 2629,
#  'the aux port': 6191,
#  'aux port on': 826,
#  'port on device': 4988,
#  'on device works': 4551,
#  'device works well': 1709,
#  'works well otherwise': 7869,
#  'well otherwise the': 7415,
#  'otherwise the packing': 4754,
#  'the packing and': 6329,
#  'packing and shipping': 4799,
#  'and shipping had': 505,
#  'shipping had no': 5754,
#  'had no issues': 2604,
#  'no issues device': 4279,
#  'issues device has': 3278,
#  'device has green': 1697,
#  'has green led': 2648,
#  'green led to': 2598,
#  'led to tell': 3725,
#  'to tell you': 6840,
#  'tell you its': 6113,
#  'you its switched': 7974,
#  'its switched on': 3563,
#  'this is not much': 6591,
#  'is not much better': 3149,
#  'not much better than': 4346,
#  'much better than the': 4113,
#  'better than the dac': 979,
#  'than the dac on': 6132,
#  'the dac on my': 6242,
#  'dac on my laptop': 1616,
#  'on my laptop the': 4571,
#  'my laptop the major': 4170,
#  'laptop the major issue': 3704,
#  'the major issue is': 6302,
#  'major issue is it': 3867,
#  'issue is it keeps': 3265,
#  'is it keeps getting': 3114,
#  'it keeps getting disconnected': 3431,
#  'keeps getting disconnected randomly': 3638,
#  'getting disconnected randomly and': 2437,
#  'disconnected randomly and frequently': 1775,
#  'randomly and frequently from': 5463,
#  'and frequently from the': 379,
#  'frequently from the laptop': 2349,
#  'from the laptop usb': 2379,
#  'the laptop usb port': 6285,
#  'laptop usb port have': 3707,
#  'usb port have nothing': 7011,
#  'port have nothing plugged': 4973,
#  'have nothing plugged into': 2684,
#  'nothing plugged into the': 4426,
#  'plugged into the usb': 4945,
#  'into the usb ports': 3032,
#  'the usb ports on': 6439,
#  'usb ports on the': 7034,
#  'ports on the device': 5026,
#  'on the device and': 4576,
#  'the device and it': 6248,
#  'device and it just': 1692,
#  'and it just keeps': 414,
#  'it just keeps happening': 3428,
#  'just keeps happening the': 3617,
#  'keeps happening the aux': 3641,
#  'happening the aux port': 2630,
#  'the aux port on': 6192,
#  'aux port on device': 827,
#  'port on device works': 4989,
#  'on device works well': 4552,
#  'device works well otherwise': 1710,
#  'works well otherwise the': 7870,
#  'well otherwise the packing': 7416,
#  'otherwise the packing and': 4755,
#  'the packing and shipping': 6330,
#  'packing and shipping had': 4800,
#  'and shipping had no': 506,
#  'shipping had no issues': 5755,
#  'had no issues device': 2605,
#  'no issues device has': 4280,
#  'issues device has green': 3279,
#  'device has green led': 1698,
#  'has green led to': 2649,
#  'green led to tell': 2599,
#  'led to tell you': 3726,
#  'to tell you its': 6841,
#  'tell you its switched': 6114,
#  'you its switched on': 7975,
#  'audio port': 780,
#  'port not': 4982,
#  'working usb': 7843,
#  'port only': 4990,
#  'only working': 4670,
#  'working very': 7846,
#  'very bad': 7208,
#  'bad sound': 893,
#  'sound port': 5941,
#  'working mice': 7801,
#  'mice port': 3946,
#  'working only': 7804,
#  'only usb': 4662,
#  'usb working': 7063,
#  'audio port not': 783,
#  'port not working': 4983,
#  'not working usb': 4413,
#  'working usb port': 7844,
#  'usb port only': 7016,
#  'port only working': 4991,
#  'only working very': 4671,
#  'working very bad': 7847,
#  'very bad sound': 7216,
#  'bad sound port': 894,
#  'sound port not': 5944,
#  'not working mice': 4395,
#  'working mice port': 7802,
#  'mice port not': 3947,
#  'not working only': 4397,
#  'working only usb': 7805,
#  'only usb working': 4663,
#  'audio port not working': 784,
#  'port not working usb': 4986,
#  'not working usb port': 4414,
#  'working usb port only': 7845,
#  'usb port only working': 7017,
#  'port only working very': 4992,
#  'only working very bad': 4672,
#  'working very bad sound': 7848,
#  'very bad sound port': 7217,
#  'bad sound port not': 895,
#  'sound port not working': 5945,
#  'port not working mice': 4984,
#  'not working mice port': 4396,
#  'working mice port not': 7803,
#  'mice port not working': 3948,
#  'port not working only': 4985,
#  'not working only usb': 4398,
#  'working only usb working': 7806,
#  'waste of': 7368,
#  'of money': 4472,
#  'money it': 4035,
#  'it makes': 3434,
#  'makes noise': 3876,
#  'noise do': 4298,
#  'do recommend': 1832,
#  'recommend for': 5529,
#  'for stream': 2284,
#  'stream or': 6043,
#  'or any': 4680,
#  'any recording': 602,
#  'recording purpose': 5557,
#  'purpose please': 5358,
#  'please go': 4917,
#  'go for': 2452,
#  'for other': 2255,
#  'other valuable': 4740,
#  'valuable product': 7184,
#  'product and': 5137,
#  'and also': 312,
#  'also it': 235,
#  'it does': 3347,
#  'does support': 1865,
#  'support stereo': 6084,
#  'stereo mic': 6012,
#  'mic in': 3932,
#  'in only': 2946,
#  'only single': 4657,
#  'single channel': 5791,
#  'waste of money': 7369,
#  'of money it': 4473,
#  'money it makes': 4036,
#  'it makes noise': 3437,
#  'makes noise do': 3877,
#  'noise do recommend': 4299,
#  'do recommend for': 1833,
#  'recommend for stream': 5530,
#  'for stream or': 2285,
#  'stream or any': 6044,
#  'or any recording': 4681,
#  'any recording purpose': 603,
#  'recording purpose please': 5558,
#  'purpose please go': 5359,
#  'please go for': 4918,
#  'go for other': 2458,
#  'for other valuable': 2256,
#  'other valuable product': 4741,
#  'valuable product and': 7185,
#  'product and also': 5138,
#  'and also it': 315,
#  'also it does': 236,
#  'it does support': 3350,
#  'does support stereo': 1866,
#  'support stereo mic': 6085,
#  'stereo mic in': 6013,
#  'mic in only': 3933,
#  'in only single': 2947,
#  'only single channel': 4658,
#  'waste of money it': 7370,
#  'of money it makes': 4474,
#  'money it makes noise': 4037,
#  'it makes noise do': 3438,
#  'makes noise do recommend': 3878,
#  'noise do recommend for': 4300,
#  'do recommend for stream': 1834,
#  'recommend for stream or': 5531,
#  'for stream or any': 2286,
#  'stream or any recording': 6045,
#  'or any recording purpose': 4682,
#  'any recording purpose please': 604,
#  'recording purpose please go': 5559,
#  'purpose please go for': 5360,
#  'please go for other': 4919,
#  'go for other valuable': 2459,
#  'for other valuable product': 2257,
#  'other valuable product and': 4742,
#  'valuable product and also': 7186,
#  'product and also it': 5139,
#  'and also it does': 316,
#  'also it does support': 237,
#  'it does support stereo': 3351,
#  'does support stereo mic': 1867,
#  'support stereo mic in': 6086,
#  'stereo mic in only': 6014,
#  'mic in only single': 3934,
#  'in only single channel': 2948,
#  'stops working': 6038,
#  'working after': 7741,
#  'after hrsgiv': 127,
#  'hrsgiv few': 2816,
#  'few hrs': 2126,
#  'hrs gap': 2813,
#  'gap again': 2397,
#  'again will': 152,
#  'will start': 7545,
#  'start working': 6003,
#  'working stops': 7831,
#  'stops after': 6036,
#  'after hrs': 126,
#  'stops working after': 6039,
#  'working after hrsgiv': 7746,
#  'after hrsgiv few': 128,
#  'hrsgiv few hrs': 2817,
#  'few hrs gap': 2127,
#  'hrs gap again': 2814,
#  'gap again will': 2398,
#  'again will start': 153,
#  'will start working': 7546,
#  'start working stops': 6004,
#  'working stops after': 7832,
#  'stops after hrs': 6037,
#  'stops working after hrsgiv': 6040,
#  'working after hrsgiv few': 7747,
#  'after hrsgiv few hrs': 129,
#  'hrsgiv few hrs gap': 2818,
#  'few hrs gap again': 2128,
#  'hrs gap again will': 2815,
#  'gap again will start': 2399,
#  'again will start working': 154,
#  'will start working stops': 7547,
#  'start working stops after': 6005,
#  'working stops after hrs': 7833,
#  'nice sound': 4267,
#  'my audio': 4141,
#  'audio jack': 767,
#  'jack was': 3587,
#  'working so': 7825,
#  'so ordered': 5833,
#  'ordered this': 4723,
#  'product you': 5290,
#  'you get': 7967,
#  'get extra': 2409,
#  'extra usb': 2072,
#  'ports which': 5031,
#  'which can': 7479,
#  'can be': 1291,
#  'be used': 917,
#  'used for': 7101,
#  'for wifi': 2329,
#  'wifi bluetooth': 7515,
#  'bluetooth wireless': 1011,
#  'wireless device': 7576,
#  'device adapters': 1687,
#  'adapters and': 96,
#  'and an': 319,
#  'an audio': 285,
#  'jack you': 3592,
#  'you need': 7988,
#  'need to': 4235,
#  'to purchase': 6804,
#  'purchase combiner': 5340,
#  'combiner for': 1412,
#  'for audio': 2182,
#  'jack and': 3570,
#  'and microphone': 447,
#  'microphone if': 3955,
#  'if you': 2881,
#  'you plan': 7992,
#  'plan for': 4894,
#  'for using': 2320,
#  'using headphone': 7153,
#  'headphone for': 2721,
#  'for calling': 2193,
#  'calling and': 1279,
#  'and attending': 322,
#  'attending online': 730,
#  'online meetings': 4630,
#  'my audio jack': 4142,
#  'audio jack was': 772,
#  'jack was not': 3590,
#  'not working so': 4405,
#  'working so ordered': 7826,
#  'so ordered this': 5834,
#  'ordered this product': 4724,
#  'this product you': 6651,
#  'product you get': 5291,
#  'you get extra': 7968,
#  'get extra usb': 2410,
#  'extra usb ports': 2073,
#  'usb ports which': 7037,
#  'ports which can': 5034,
#  'which can be': 7480,
#  'can be used': 1294,
#  'be used for': 918,
#  'used for wifi': 7102,
#  'for wifi bluetooth': 2330,
#  'wifi bluetooth wireless': 7516,
#  'bluetooth wireless device': 1012,
#  'wireless device adapters': 7577,
#  'device adapters and': 1688,
#  'adapters and an': 97,
#  'and an audio': 320,
#  'an audio jack': 286,
#  'audio jack you': 775,
#  'jack you need': 3593,
#  'you need to': 7989,
#  'need to purchase': 4236,
#  'to purchase combiner': 6805,
#  'purchase combiner for': 5341,
#  'combiner for audio': 1413,
#  'for audio jack': 2185,
#  'audio jack and': 768,
#  'jack and microphone': 3571,
#  'and microphone if': 450,
#  'microphone if you': 3956,
#  'if you plan': 2892,
#  'you plan for': 7993,
#  'plan for using': 4895,
#  'for using headphone': 2321,
#  'using headphone for': 7154,
#  'headphone for calling': 2722,
#  'for calling and': 2194,
#  'calling and attending': 1280,
#  'and attending online': 323,
#  'attending online meetings': 731,
#  'my audio jack was': 4143,
#  'audio jack was not': 774,
#  'jack was not working': 3591,
#  'was not working so': 7337,
#  'not working so ordered': 4406,
#  'working so ordered this': 7827,
#  'so ordered this product': 5835,
#  'ordered this product you': 4725,
#  'this product you get': 6652,
#  'product you get extra': 5292,
#  'you get extra usb': 7969,
#  'get extra usb ports': 2411,
#  'extra usb ports which': 2075,
#  'usb ports which can': 7039,
#  'ports which can be': 5035,
#  'which can be used': 7481,
#  'can be used for': 1295,
#  'be used for wifi': 919,
#  'used for wifi bluetooth': 7103,
#  'for wifi bluetooth wireless': 2331,
#  'wifi bluetooth wireless device': 7517,
#  'bluetooth wireless device adapters': 1013,
#  'wireless device adapters and': 7578,
#  'device adapters and an': 1689,
#  'adapters and an audio': 98,
#  'and an audio jack': 321,
#  'an audio jack you': 287,
#  'audio jack you need': 776,
#  'jack you need to': 3594,
#  'you need to purchase': 7990,
#  'need to purchase combiner': 4237,
#  'to purchase combiner for': 6806,
#  'purchase combiner for audio': 5342,
#  'combiner for audio jack': 1414,
#  'for audio jack and': 2186,
#  'audio jack and microphone': 769,
#  'jack and microphone if': 3572,
#  'and microphone if you': 451,
#  'microphone if you plan': 3957,
#  'if you plan for': 2893,
#  'you plan for using': 7994,
#  'plan for using headphone': 4896,
#  'for using headphone for': 2322,
#  'using headphone for calling': 7155,
#  'headphone for calling and': 2723,
#  'for calling and attending': 2195,
#  'calling and attending online': 1281,
#  'and attending online meetings': 324,
#  'it cheap': 3331,
#  'the product': 6353,
#  'product is': 5194,
#  'is great': 3103,
#  'great but': 2576,
#  'but the': 1146,
#  'the cable': 6210,
#  'cable provided': 1256,
#  'provided is': 5331,
#  'good am': 2474,
#  'am using': 269,
#  'using my': 7164,
#  'my old': 4190,
#  'old printer': 4534,
#  'printer cable': 5095,
#  'cable the': 1259,
#  'the provided': 6376,
#  'provided cable': 5328,
#  'cable keeps': 1250,
#  'keeps disconnecting': 3633,
#  'disconnecting all': 1776,
#  'all ports': 177,
#  'ports work': 5039,
#  'work have': 7708,
#  'have tested': 2695,
#  'tested mic': 6118,
#  'mic headphone': 3929,
#  'headphone port': 2732,
#  'port amplifies': 4960,
#  'amplifies the': 280,
#  'the sound': 6411,
#  'sound lot': 5929,
#  'lot am': 3819,
#  'am listening': 260,
#  'listening on': 3770,
#  'on volume': 4584,
#  'volume of': 7284,
#  'of compared': 4451,
#  'compared to': 1448,
#  'to around': 6726,
#  'around 25': 652,
#  '25 on': 19,
#  'my internal': 4156,
#  'internal sound': 3022,
#  'sound card': 5888,
#  'card have': 1337,
#  'have been': 2668,
#  'been using': 938,
#  'using for': 7150,
#  'for days': 2196,
#  'days will': 1638,
#  'will update': 7548,
#  'update after': 6937,
#  'after few': 121,
#  'few months': 2129,
#  'months have': 4065,
#  'tested at': 6115,
#  'at high': 704,
#  'high volumes': 2784,
#  'volumes as': 7292,
#  'as it': 668,
#  'it is': 3405,
#  'is too': 3226,
#  'too loud': 6874,
#  'the product is': 6360,
#  'product is great': 5209,
#  'is great but': 3104,
#  'great but the': 2577,
#  'but the cable': 1149,
#  'the cable provided': 6213,
#  'cable provided is': 1257,
#  'provided is not': 5332,
#  'is not good': 3144,
#  'not good am': 4331,
#  'good am using': 2477,
#  'am using my': 270,
#  'using my old': 7167,
#  'my old printer': 4191,
#  'old printer cable': 4535,
#  'printer cable the': 5096,
#  'cable the provided': 1262,
#  'the provided cable': 6377,
#  'provided cable keeps': 5329,
#  'cable keeps disconnecting': 1251,
#  'keeps disconnecting all': 3634,
#  'disconnecting all ports': 1777,
#  'all ports work': 178,
#  'ports work have': 5040,
#  'work have tested': 7711,
#  'have tested mic': 2698,
#  'tested mic headphone': 6119,
#  'mic headphone port': 3930,
#  'headphone port amplifies': 2733,
#  'port amplifies the': 4961,
#  'amplifies the sound': 281,
#  'the sound lot': 6412,
#  'sound lot am': 5930,
#  'lot am listening': 3820,
#  'am listening on': 261,
#  'listening on volume': 3771,
#  'on volume of': 4585,
#  'volume of compared': 7287,
#  'of compared to': 4452,
#  'compared to around': 1449,
#  'to around 25': 6727,
#  'around 25 on': 653,
#  '25 on my': 20,
#  'on my internal': 4568,
#  'my internal sound': 4157,
#  'internal sound card': 3023,
#  'sound card have': 5897,
#  'card have been': 1338,
#  'have been using': 2669,
#  'been using for': 939,
#  'using for days': 7151,
#  'for days will': 2197,
#  'days will update': 1639,
#  'will update after': 7549,
#  'update after few': 6938,
#  'after few months': 124,
#  'few months have': 2130,
#  'months have tested': 4066,
#  'have tested at': 2696,
#  'tested at high': 6116,
#  'at high volumes': 705,
#  'high volumes as': 2785,
#  'volumes as it': 7293,
#  'as it is': 669,
#  'it is too': 3422,
#  'is too loud': 3227,
#  'the product is great': 6365,
#  'product is great but': 5210,
#  'is great but the': 3105,
#  'great but the cable': 2578,
#  'but the cable provided': 1150,
#  'the cable provided is': 6214,
#  'cable provided is not': 1258,
#  'provided is not good': 5333,
#  'is not good am': 3145,
#  'not good am using': 4332,
#  'good am using my': 2478,
#  'am using my old': 271,
#  'using my old printer': 7168,
#  'my old printer cable': 4192,
#  'old printer cable the': 4536,
#  'printer cable the provided': 5097,
#  'cable the provided cable': 1263,
#  'the provided cable keeps': 6378,
#  'provided cable keeps disconnecting': 5330,
#  'cable keeps disconnecting all': 1252,
#  'keeps disconnecting all ports': 3635,
#  'disconnecting all ports work': 1778,
#  'all ports work have': 179,
#  'ports work have tested': 5041,
#  'work have tested mic': 7712,
#  'have tested mic headphone': 2699,
#  'tested mic headphone port': 6120,
#  'mic headphone port amplifies': 3931,
#  'headphone port amplifies the': 2734,
#  'port amplifies the sound': 4962,
#  'amplifies the sound lot': 282,
#  'the sound lot am': 6413,
#  'sound lot am listening': 5931,
#  'lot am listening on': 3821,
#  'am listening on volume': 262,
#  'listening on volume of': 3772,
#  'on volume of compared': 4586,
#  'volume of compared to': 7288,
#  'of compared to around': 4453,
#  'compared to around 25': 1450,
#  'to around 25 on': 6728,
#  'around 25 on my': 654,
#  '25 on my internal': 21,
#  'on my internal sound': 4569,
#  'my internal sound card': 4158,
#  'internal sound card have': 3024,
#  'sound card have been': 5898,
#  'card have been using': 1339,
#  'have been using for': 2670,
#  'been using for days': 940,
#  'using for days will': 7152,
#  'for days will update': 2198,
#  'days will update after': 1640,
#  'will update after few': 7550,
#  'update after few months': 6939,
#  'after few months have': 125,
#  'few months have tested': 2131,
#  'months have tested at': 4067,
#  'have tested at high': 2697,
#  'tested at high volumes': 6117,
#  'at high volumes as': 706,
#  'high volumes as it': 2786,
#  'volumes as it is': 7294,
#  'as it is too': 670,
#  'it is too loud': 3423,
#  'when kepp': 7447,
#  'kepp the': 3645,
#  'the volume': 6444,
#  'volume at': 7272,
#  'at percent': 713,
#  'percent it': 4845,
#  'it gives': 3388,
#  'gives the': 2446,
#  'of 10': 4445,
#  '10 percent': 7,
#  'percent which': 4848,
#  'which is': 7485,
#  'is very': 3234,
#  'very loud': 7231,
#  'loud and': 3829,
#  'microphone does': 3949,
#  'does not': 1856,
#  'not work': 4373,
#  'work properly': 7723,
#  'when kepp the': 7448,
#  'kepp the volume': 3646,
#  'the volume at': 6445,
#  'volume at percent': 7273,
#  'at percent it': 714,
#  'percent it gives': 4846,
#  'it gives the': 3389,
#  'gives the volume': 2447,
#  'the volume of': 6447,
#  'volume of 10': 7285,
#  'of 10 percent': 4446,
#  '10 percent which': 8,
#  'percent which is': 4849,
#  'which is very': 7486,
#  'is very loud': 3238,
#  'very loud and': 7232,
#  'loud and microphone': 3830,
#  'and microphone does': 448,
#  'microphone does not': 3950,
#  'does not work': 1859,
#  'not work properly': 4378,
#  'when kepp the volume': 7449,
#  'kepp the volume at': 3647,
#  'the volume at percent': 6446,
#  'volume at percent it': 7274,
#  'at percent it gives': 715,
#  'percent it gives the': 4847,
#  'it gives the volume': 3390,
#  'gives the volume of': 2448,
#  'the volume of 10': 6448,
#  'volume of 10 percent': 7286,
#  'of 10 percent which': 4447,
#  '10 percent which is': 9,
#  'percent which is very': 4850,
#  'which is very loud': 7487,
#  'is very loud and': 3239,
#  'very loud and microphone': 7233,
#  'loud and microphone does': 3831,
#  'and microphone does not': 449,
#  'microphone does not work': 3951,
#  'does not work properly': 1861,
#  'do buy': 1814,
#  'product it': 5227,
#  'it not': 3442,
#  'working properly': 7810,
#  'properly connecting': 5305,
#  'connecting for': 1520,
#  'for one': 2252,
#  'one minute': 4608,
#  'minute and': 3993,
#  'and disconnecting': 365,
#  'disconnecting and': 1779,
#  'also use': 246,
#  'use device': 7070,
#  'device troubleshooting': 1702,
#  'troubleshooting option': 6884,
#  'option in': 4674,
#  'in windows': 2990,
#  'windows 10': 7560,
#  '10 its': 4,
#  'its not': 3550,
#  'working have': 7790,
#  'have replaced': 2692,
#  'replaced the': 5578,
#  'the order': 6317,
#  'order now': 4717,
#  'now expecting': 4439,
#  'expecting nice': 2034,
#  'nice one': 4257,
#  'do buy this': 1818,
#  'buy this product': 1221,
#  'this product it': 6646,
#  'product it not': 5230,
#  'it not working': 3445,
#  ...}

# %%
vocab = vectorizer.vocabulary_.keys()

# tags given by amazon
tags = set([
  'value for money',
  'sound card',
  'sound quality',
  'usb hub',
  'waste of money',
  'works well',
  'good quality',
  'dont buy',
  'hard drive',
  'audio jack',
  'build quality',
  'working fine',
  'usb port',
  'keeps disconnecting',
  'printer cable',
  'stopped working',
  'worth buying',
  'working properly',
  'audio quality',
  'recommend not to buy'
])

found_tags = set()

for k in vocab:
  for t in tags:
    if t in k:
      found_tags.add(t)

# %%
found_tags
# Out:
# {'audio jack',
#  'audio quality',
#  'build quality',
#  'dont buy',
#  'good quality',
#  'hard drive',
#  'keeps disconnecting',
#  'printer cable',
#  'recommend not to buy',
#  'sound card',
#  'sound quality',
#  'stopped working',
#  'usb hub',
#  'usb port',
#  'value for money',
#  'waste of money',
#  'working fine',
#  'working properly',
#  'works well',
#  'worth buying'}

# %%
missed_tags = tags - found_tags
missed_tags
# Out:
# set()

# %%
(
    pd.DataFrame(vectorizer.vocabulary_.items(), 
                 columns=['word', 'count'])
    .sort_values(by='count', ascending=False)
    .iloc[:20]
)
# Out:
#                            word  count
# 5616  your systems sounds cards   8046
# 5608        your systems sounds   8045
# 5600               your systems   8044
# 2809       your phone and works   8043
# 2753             your phone and   8042
# 2699                 your phone   8041
# 7836                 your money   8040
# 4814     your microphone go for   8039
# 4797         your microphone go   8038
# 4782            your microphone   8037
# 3359          your level to 100   8036
# 3309              your level to   8035
# 3261                 your level   8034
# 4617       your laptop 5mm slot   8033
# 4467            your laptop 5mm   8032
# 4321                your laptop   8031
# 6541          your ears save up   8030
# 6227             your ears save   8029
# 5921                  your ears   8028
# 6476      your computer it cuts   8027

# %% [markdown]
# # Topic Modelling

# %%
def get_reviews_text(reviews):
  texts = [r['review'] for r in reviews]
  return preprocess_texts(texts)

def pos_filter(tokens):
  tagged = nltk.pos_tag(tokens)
  return [
    word for word, pos in tagged 
    if len(pos) >= 2 and pos[:2] in ['NN', 'JJ']
  ]

def preprocess_texts(texts):
  # return tfidf_preprocess(texts)
  texts = [text.lower() for text in texts]
  texts = [word_tokenize(t) for t in texts]
  texts = [[word for word in t if word not in string.punctuation] for t in texts]
  texts = [pos_filter(text) for text in texts]
  return texts

# %%
reviews_texts = get_reviews_text(reviews)
reviews_dict = Dictionary(reviews_texts)
reviews_corpus = [reviews_dict.doc2bow(text) for text in reviews_texts]

# %%
lda = LdaModel(reviews_corpus, id2word=reviews_dict, num_topics=10)

# %%
# topics_humanized = [(topic[0], [(reviews_dict[int(word[0])], word[1]) for word in topic[1]] )for topic in lda.show_topics(formatted=False)]
# topics_humanized

# %%
lda.print_topics()
# Out:
# [(0,
#   '0.084*"good" + 0.069*"quality" + 0.024*"price" + 0.023*"sound" + 0.015*"product" + 0.013*"usb" + 0.013*"ports" + 0.009*"microphone" + 0.008*"awesome" + 0.008*"product.."'),
#  (1,
#   '0.045*"product" + 0.022*"i" + 0.017*"device" + 0.012*"quality" + 0.011*"money" + 0.011*"waste" + 0.011*"purpose" + 0.011*"stops" + 0.011*"mic" + 0.011*"valuable"'),
#  (2,
#   '0.038*"product" + 0.031*"sound" + 0.025*"money" + 0.025*"usb" + 0.025*"i" + 0.025*"cable" + 0.025*"value" + 0.019*"audio" + 0.019*"microphone" + 0.019*"work"'),
#  (3,
#   '0.085*"product" + 0.039*"usb" + 0.032*"i" + 0.031*"time" + 0.024*"ports" + 0.017*"quality" + 0.016*"money" + 0.016*"value" + 0.016*"second" + 0.016*"month"'),
#  (4,
#   '0.079*"i" + 0.041*"product" + 0.033*"usb" + 0.025*"good" + 0.022*"quality" + 0.020*"audio" + 0.019*"laptop" + 0.016*"sound" + 0.015*"cheap" + 0.013*"cable"'),
#  (5,
#   '0.032*"i" + 0.029*"product" + 0.023*"quality" + 0.019*"audio" + 0.015*"usb" + 0.014*"headphone" + 0.014*"money" + 0.014*"other" + 0.013*"device" + 0.012*"price"'),
#  (6,
#   '0.033*"sound" + 0.025*"usb" + 0.023*"quality" + 0.015*"audio" + 0.014*"good" + 0.013*"days" + 0.013*"card" + 0.013*"ports" + 0.013*"external" + 0.012*"perfect"'),
#  (7,
#   '0.063*"product" + 0.062*"usb" + 0.046*"i" + 0.046*"good" + 0.038*"port" + 0.033*"quality" + 0.033*"audio" + 0.030*"sound" + 0.017*"money" + 0.015*"hub"'),
#  (8,
#   '0.043*"product" + 0.030*"usb" + 0.028*"audio" + 0.028*"bad" + 0.017*"time" + 0.015*"i" + 0.014*"great" + 0.014*"easy" + 0.014*"’" + 0.014*"stops"'),
#  (9,
#   '0.057*"i" + 0.036*"product" + 0.032*"sound" + 0.021*"quality" + 0.018*"usb" + 0.015*"output" + 0.015*"mac" + 0.015*"nice" + 0.015*"cable" + 0.013*"value"')]

# %%
import pyLDAvis.gensim_models as gensimvis

# %%
gensimvis.prepare(lda, reviews_corpus, reviews_dict)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 7      0.074377 -0.019390       1        1  23.898324
# 4      0.100580 -0.005751       2        1  20.566482
# 9      0.049324 -0.003969       3        1  11.245302
# 2      0.010663  0.101920       4        1   8.924151
# 8     -0.108093  0.057811       5        1   7.644130
# 0     -0.070374 -0.112452       6        1   7.251599
# 3     -0.017714  0.063820       7        1   6.510609
# 5      0.020260 -0.031398       8        1   6.234855
# 1     -0.051745 -0.019416       9        1   4.340967
# 6     -0.007279 -0.031174      10        1   3.383580, topic_info=       Term       Freq      Total Category  logprob  loglift
# 78     good  32.000000  32.000000  Default  30.0000  30.0000
# 10  product  57.000000  57.000000  Default  29.0000  29.0000
# 14  quality  30.000000  30.000000  Default  28.0000  28.0000
# 80        i  54.000000  54.000000  Default  27.0000  27.0000
# 15    sound  27.000000  27.000000  Default  26.0000  26.0000
# ..      ...        ...        ...      ...      ...      ...
# 14  quality   1.015057  30.814260  Topic10  -3.7534  -0.0268
# 19      usb   1.091247  43.499072  Topic10  -3.6811  -0.2992
# 17    money   0.505811  14.873139  Topic10  -4.4500   0.0051
# 42    audio   0.641268  24.965863  Topic10  -4.2127  -0.2756
# 78     good   0.626807  32.974300  Topic10  -4.2355  -0.5766
#
# [525 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 466       7  0.764037     .and
# 163       1  0.274553     able
# 163       2  0.274553     able
# 163       6  0.274553     able
# 310       2  0.472149  adapter
# ...     ...       ...      ...
# 431       5  0.748591    wrong
# 202      10  0.881108      yes
# 121       2  0.240013        ’
# 121       4  0.240013        ’
# 121       5  0.240013        ’
#
# [586 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[8, 5, 10, 3, 9, 1, 4, 6, 2, 7])

# %%
topic_names = [
    # 'usb port disconnecting',
    # 'replacement',
    # 'not durable',
    # 'usb port not working',
    # 'earphone port',
    # 'great sound',
    # 'works well',
    # 'works well',
    # 'never buy',
    # 'usb port disconnecting',
]

# %%
other_texts = ['audio port not working']
other_texts = preprocess_texts(other_texts)
other_corpus = [reviews_dict.doc2bow(text) for text in other_texts]

# %%
[[(reviews_dict[token[0]], token[1]) for token in doc] for doc in other_corpus]
# Out:
# [[('port', 1), ('audio', 1)]]

# %%
unseen_doc = other_corpus[0]

# %%
vector = lda[unseen_doc]

# %%
vector
# Out:
# [(0, 0.033334162),
#  (1, 0.033333812),
#  (2, 0.03333736),
#  (3, 0.033333454),
#  (4, 0.03333918),
#  (5, 0.033337966),
#  (6, 0.033335414),
#  (7, 0.6999748),
#  (8, 0.033338476),
#  (9, 0.033335377)]

# %%
[(topic_names[v[0]], v[1])for v in vector]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-68ac63427698> in <module>()
# ----> 1 [(topic_names[v[0]], v[1])for v in vector]
#
# <ipython-input-39-68ac63427698> in <listcomp>(.0)
# ----> 1 [(topic_names[v[0]], v[1])for v in vector]
#
# NameError: name 'topic_names' is not defined

# %% [markdown]
# # Keybert

# %%
kb = KeyBERT()
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def extract_keyphrases(kb, review):
  doc = review['review']
  return kb.extract_keywords(doc, keyphrase_ngram_range=(2, 3))

# %%
keyphrases = [extract_keyphrases(kb, review) for review in reviews]

# %%
keyphrases
# Out:
# [[('good earphones connection', 0.6529),
#   ('earphones connection', 0.5931),
#   ('earphones connection working', 0.5829),
#   ('good earphones', 0.5519),
#   ('connection working correctly', 0.3248)],
#  [('kharab ho gaya', 0.9353),
#   ('jaldi kharab ho', 0.8297),
#   ('jaldi kharab', 0.751),
#   ('kharab ho', 0.7116),
#   ('ho gaya', 0.6869)],
#  [('product stopped working', 0.6683),
#   ('product stopped', 0.6049),
#   ('month product stopped', 0.5994),
#   ('stopped working', 0.4646),
#   ('replace return product', 0.414)],
#  [('sound quality', 0.6605),
#   ('sound quality just', 0.6472),
#   ('great use earphones', 0.53),
#   ('earphones headphones', 0.5012),
#   ('use earphones', 0.4975)],
#  [('long cable usb', 0.765),
#   ('nice long cable', 0.738),
#   ('long cable', 0.6934),
#   ('cable usb', 0.6181),
#   ('cable usb ports', 0.587)],
#  [('dislike free aslo', 0.8212),
#   ('free aslo', 0.7583),
#   ('super dislike free', 0.5704),
#   ('dislike free', 0.4861),
#   ('super dislike', 0.391)],
#  [],
#  [('better dac laptop', 0.7101),
#   ('dac laptop', 0.6931),
#   ('dac laptop major', 0.6068),
#   ('better dac', 0.5634),
#   ('laptop usb port', 0.4595)],
#  [],
#  [('usb port working', 0.681),
#   ('bad sound port', 0.6661),
#   ('usb working', 0.6626),
#   ('audio port working', 0.6495),
#   ('working usb port', 0.6442)],
#  [('stream recording purpose', 0.7758),
#   ('stream recording', 0.7751),
#   ('recommend stream recording', 0.7462),
#   ('mic single channel', 0.6285),
#   ('stereo mic', 0.6158)],
#  [('stops working', 0.7007),
#   ('stops working hrsgiv', 0.6647),
#   ('working stops', 0.6386),
#   ('working stops hrs', 0.6183),
#   ('start working stops', 0.5782)],
#  [('waste money', 0.9244)],
#  [('nice sound', 1.0)],
#  [('audio jack need', 0.5691),
#   ('combiner audio jack', 0.5435),
#   ('audio jack', 0.5395),
#   ('adapters audio jack', 0.5326),
#   ('device adapters audio', 0.5309)],
#  [],
#  [('product great cable', 0.5685),
#   ('haven tested mic', 0.5168),
#   ('tested mic headphone', 0.497),
#   ('mic headphone port', 0.4926),
#   ('mic headphone', 0.4736)],
#  [('percent loud microphone', 0.7457),
#   ('loud microphone', 0.6832),
#   ('loud microphone does', 0.6546),
#   ('microphone does work', 0.5962),
#   ('gives volume', 0.5414)],
#  [('connecting minute disconnecting', 0.5136),
#   ('use device troubleshooting', 0.5121),
#   ('disconnecting use device', 0.4988),
#   ('working properly connecting', 0.4864),
#   ('properly connecting', 0.4856)],
#  [('good product', 0.8147)],
#  [('crap cheap material', 0.4374),
#   ('disconnected high brand', 0.4126),
#   ('complete crap cheap', 0.4121),
#   ('gets disconnected', 0.3804),
#   ('crap cheap', 0.3745)],
#  [('increases loudnessand audio', 0.7614),
#   ('dosent improve sound', 0.7335),
#   ('increases loudnessand', 0.6681),
#   ('sound increases loudnessand', 0.642),
#   ('improve sound increases', 0.6322)],
#  [('said product unreturnable', 0.5166),
#   ('return said product', 0.4847),
#   ('product unreturnable', 0.4847),
#   ('product unreturnable send', 0.4473),
#   ('unreturnable send money', 0.429)],
#  [('usb audio card', 0.6093),
#   ('voice breaks', 0.6091),
#   ('replaced voice breaks', 0.6003),
#   ('audio card', 0.5929),
#   ('usb audio', 0.5681)],
#  [('product hot easily', 0.4311),
#   ('product hot', 0.4071),
#   ('disconnects calls gaming', 0.3866),
#   ('hot easily', 0.3088),
#   ('calls gaming', 0.3074)],
#  [('using hangingsound breaking', 0.7732),
#   ('hangingsound breaking', 0.7423),
#   ('hour using hangingsound', 0.7311),
#   ('using hangingsound', 0.6854),
#   ('hour using', 0.4193)],
#  [('product looking forworth', 0.8554),
#   ('looking forworth buy', 0.7218),
#   ('forworth buy', 0.6551),
#   ('looking forworth', 0.6508),
#   ('perfect product looking', 0.522)],
#  [('mention sound quality', 0.6564),
#   ('sound quality sheerness', 0.6332),
#   ('quality sheerness value', 0.5775),
#   ('sound quality', 0.5654),
#   ('mention sound', 0.5095)],
#  [],
#  [('drop connection', 0.5266),
#   ('month drop connection', 0.5161),
#   ('drop connection frequently', 0.4979),
#   ('connection frequently working', 0.4333),
#   ('connection frequently', 0.4175)],
#  [('phone usb cable', 0.744),
#   ('phone usb', 0.7115),
#   ('accept phone usb', 0.6707),
#   ('helpful usb does', 0.6653),
#   ('usb cable', 0.5966)],
#  [('noise problem pa', 0.6291),
#   ('facing noise problem', 0.5783),
#   ('recommend facing noise', 0.5389),
#   ('noise problem', 0.4878),
#   ('facing noise', 0.4574)],
#  [('th stoped working', 0.5465),
#   ('stoped working dont', 0.5208),
#   ('working dont buy', 0.5005),
#   ('stoped working', 0.4608),
#   ('1st working', 0.3517)],
#  [('quality bad product', 0.642),
#   ('used product bad', 0.6305),
#   ('product quality bad', 0.6277),
#   ('product comes dust', 0.6156),
#   ('product quality', 0.5802)],
#  [('product good usb', 0.6733),
#   ('ps4 good quality', 0.6625),
#   ('pc ps4 good', 0.6372),
#   ('good usb cable', 0.637),
#   ('ps4 good', 0.5813)],
#  [('excellent product price', 0.7142),
#   ('price little high', 0.6841),
#   ('product price little', 0.6595),
#   ('price little', 0.5848),
#   ('excellent product', 0.5701)],
#  [('worst product failed', 0.6948),
#   ('sorting mother board', 0.6227),
#   ('worst product', 0.5909),
#   ('mother board', 0.5904),
#   ('product failed', 0.499)],
#  [('stopped working days', 0.7039),
#   ('stopped working', 0.6731),
#   ('waste money', 0.4591),
#   ('days waste money', 0.4582),
#   ('days waste', 0.3756)],
#  [('product working', 0.6548)],
#  [('good quality', 1.0)],
#  [('mouse combo usb', 0.5839),
#   ('combo usb', 0.5416),
#   ('connect mouse keyboard', 0.5389),
#   ('laptop keyboards', 0.5236),
#   ('combo usb able', 0.5235)],
#  [('awesomesolved usb aux', 0.6068),
#   ('sound quality', 0.594),
#   ('usb aux ports', 0.5806),
#   ('aux ports problem', 0.5745),
#   ('usb aux', 0.5519)],
#  [('audio cards', 0.572),
#   ('product headphone port', 0.5706),
#   ('cheap audio cards', 0.5527),
#   ('headphone port', 0.5404),
#   ('headphone port working', 0.5289)],
#  [('usb port parallel', 0.7218),
#   ('multiple usb port', 0.6858),
#   ('use multiple usb', 0.6652),
#   ('multiple usb', 0.6561),
#   ('audio port working', 0.5539)],
#  [('mac mixer', 0.6122),
#   ('sound mixer mac', 0.6107),
#   ('mixer mac', 0.603),
#   ('live streaming purpose', 0.5981),
#   ('mac mixer works', 0.5968)],
#  [('worst product', 1.0)],
#  [('sound card external', 0.5709),
#   ('audio sound card', 0.5592),
#   ('card external headphone', 0.4989),
#   ('sound card', 0.4877),
#   ('yes best audio', 0.4871)],
#  [],
#  [('overall good', 0.6625),
#   ('overall good kind', 0.6249),
#   ('good kind price', 0.6079),
#   ('kind price', 0.5335),
#   ('good kind', 0.2954)],
#  [('sound disturbing', 1.0)],
#  [('bm 800 microphonei', 0.6851),
#   ('microphonei recommend bm', 0.6272),
#   ('800 microphonei recommend', 0.5587),
#   ('works bm 800', 0.5416),
#   ('vocals recording works', 0.5281)],
#  [('cable provided', 0.5778),
#   ('issue cable provided', 0.5662),
#   ('issue cable', 0.5412),
#   ('got issue cable', 0.5123),
#   ('value money got', 0.4625)],
#  [('worst built quality', 1.0),
#   ('built quality', 0.8557),
#   ('worst built', 0.7733)],
#  [('soundbut work cubase', 0.6182),
#   ('works starmaker singsuperb', 0.6004),
#   ('starmaker singsuperb', 0.5588),
#   ('soundbut work', 0.5298),
#   ('audacity otg connect', 0.4979)],
#  [('jack mouse keyboard', 0.5999),
#   ('works fine usb', 0.5984),
#   ('mouse keyboard', 0.5878),
#   ('headphone jack mouse', 0.5654),
#   ('usb headphone', 0.547)],
#  [('mic input doesn', 0.8594),
#   ('mic input', 0.7858),
#   ('input doesn work', 0.6004),
#   ('input doesn', 0.4799),
#   ('doesn work', 0.321)],
#  [('quality ontime delivery', 0.702),
#   ('ontime delivery', 0.5998),
#   ('working good quality', 0.5815),
#   ('good quality ontime', 0.5757),
#   ('nice working good', 0.5683)],
#  [('product working properlythis', 0.6888),
#   ('product working', 0.5798),
#   ('properlythis experience disappointing', 0.5739),
#   ('working properlythis', 0.5188),
#   ('working properlythis experience', 0.4981)],
#  [('money laptop audio', 0.6251),
#   ('laptop audio', 0.6171),
#   ('usb audio utterly', 0.6094),
#   ('brand usb audio', 0.6073),
#   ('usb audio', 0.5996)],
#  [('receive usb hub', 0.8435),
#   ('usb hub recieved', 0.8425),
#   ('hub recieved wire', 0.7276),
#   ('usb hub', 0.723),
#   ('hub recieved', 0.63)],
#  [('reconnect connection stable', 0.6043),
#   ('standby necessarily disconnect', 0.593),
#   ('screen lock standby', 0.5799),
#   ('screen unlock works', 0.5353),
#   ('necessarily disconnect reconnect', 0.5106)],
#  [('quality product', 0.5723),
#   ('quality product issues', 0.5688),
#   ('nice quality product', 0.563),
#   ('product issues', 0.4739),
#   ('nice quality', 0.4241)],
#  [],
#  [('good microphone volume', 0.6687),
#   ('audio quality', 0.6662),
#   ('microphone volume low', 0.6544),
#   ('audio quality really', 0.6366),
#   ('microphone volume', 0.5738)],
#  [('nice productvery super', 0.8634),
#   ('nice productvery', 0.817),
#   ('productvery super duper', 0.7553),
#   ('productvery super', 0.6309),
#   ('super duper', 0.5326)],
#  [('3rd usb port', 0.7037),
#   ('3rd usb', 0.6205),
#   ('2nd 3rd usb', 0.6177),
#   ('usb port works', 0.6095),
#   ('usb port usb', 0.5836)],
#  [('product good audio', 0.726),
#   ('good audio listening', 0.5836),
#   ('audio listening use', 0.5628),
#   ('listening use plug', 0.5494),
#   ('audio listening', 0.5168)],
#  [('useless don buy', 0.7548),
#   ('just useless', 0.7092),
#   ('just useless don', 0.629),
#   ('useless don', 0.5483),
#   ('don buy', 0.4078)],
#  [],
#  [('usb port work', 0.8171), ('usb port', 0.7128), ('port work', 0.5279)],
#  [('makes bad noise', 0.9158), ('bad noise', 0.7791), ('makes bad', 0.5548)],
#  [('usb port detecting', 0.683),
#   ('working good usb', 0.5965),
#   ('usb port', 0.5829),
#   ('good usb port', 0.5056),
#   ('good usb', 0.4471)],
#  [('product easy use', 0.6035),
#   ('easy use', 0.5386),
#   ('product easy', 0.5036),
#   ('easy use issue', 0.4638),
#   ('wire cpu', 0.4334)],
#  [('goodpendrive working', 0.9108)],
#  [('earphone use usb', 0.6572),
#   ('usb slots simultaneously', 0.5833),
#   ('use usb slots', 0.5009),
#   ('earphone use', 0.4932),
#   ('usb slots', 0.4913)],
#  [('quality use microphone', 0.7256),
#   ('audio distance', 0.6151),
#   ('input audio distance', 0.5981),
#   ('distance audio', 0.5962),
#   ('microphone listen', 0.5929)],
#  [('using month', 0.4582),
#   ('problem using month', 0.3938),
#   ('problem using', 0.2078)],
#  [('problems asked refund', 0.4314),
#   ('disturbing computer', 0.422),
#   ('refund don original', 0.4053),
#   ('original cover', 0.4013),
#   ('asked refund', 0.4005)],
#  [('designed build quality', 0.6595),
#   ('build quality', 0.6296),
#   ('designed build', 0.5399),
#   ('build quality mark', 0.5315),
#   ('way designed build', 0.5025)],
#  [],
#  [('auto installation usb', 0.7158),
#   ('installation usb audio', 0.631),
#   ('easy auto installation', 0.614),
#   ('auto installation', 0.597),
#   ('installation usb', 0.5804)],
#  [('sound quality', 0.6175),
#   ('sound quality good', 0.5945),
#   ('pc speaker', 0.4582),
#   ('starting pc speaker', 0.4511),
#   ('pc speaker makes', 0.44)],
#  [],
#  [('problem audio adapter', 0.6414),
#   ('usb sound card', 0.5633),
#   ('audio adapter', 0.559),
#   ('problem audio', 0.515),
#   ('sound card', 0.5102)],
#  [],
#  [('worth buying output', 0.8194),
#   ('buying output', 0.6015),
#   ('buying output lot', 0.5303),
#   ('worth buying', 0.4395),
#   ('output lot disturbance', 0.415)],
#  [('usb came working', 0.6629),
#   ('usb came', 0.5523),
#   ('used cable', 0.4936),
#   ('properly used cable', 0.4846),
#   ('came working properly', 0.2736)],
#  [],
#  [('detected laptop connected', 0.698),
#   ('detected laptop', 0.6165),
#   ('laptop connected worked', 0.6091),
#   ('nit detected laptop', 0.6044),
#   ('laptop connected', 0.5604)],
#  [('good sound quality', 1.0),
#   ('sound quality', 0.9035),
#   ('good sound', 0.7477)],
#  [('sound microphone thanks', 0.5152),
#   ('wanted sound microphone', 0.4992),
#   ('sound microphone', 0.4951),
#   ('usb ports', 0.481),
#   ('extra usb ports', 0.4723)],
#  [('free performance microphone', 0.6806),
#   ('performance microphone', 0.6613),
#   ('performance microphone low', 0.6285),
#   ('noise free performance', 0.5862),
#   ('microphone low', 0.5794)],
#  [('usb hub sound', 0.5629),
#   ('usb cable hp', 0.5358),
#   ('pendrive speaker cable', 0.5289),
#   ('price getting usb', 0.5194),
#   ('usb hub', 0.5188)],
#  [('returned product', 0.3088),
#   ('returned product working', 0.3032),
#   ('product working', 0.2818)],
#  [('ps4 supports quite', 0.6101),
#   ('used ps4 supports', 0.5611),
#   ('ps4 supports', 0.5601),
#   ('supports quite sturdy', 0.5068),
#   ('useful used ps4', 0.503)],
#  [],
#  [('headset works speakers', 0.8431),
#   ('headset works', 0.7341),
#   ('works speakers', 0.6015)],
#  [('cheap product', 1.0)],
#  [('sound street players', 0.6538),
#   ('local sound street', 0.6235),
#   ('sound street', 0.5775),
#   ('local sound', 0.5722),
#   ('digital sound local', 0.5706)],
#  [('sound digital piano', 0.6323),
#   ('digital piano', 0.59),
#   ('digital piano suggest', 0.5738),
#   ('piano output really', 0.5401),
#   ('daw using midi', 0.5318)],
#  [('product work nic', 0.8806),
#   ('work nic', 0.7669),
#   ('dis product work', 0.5214),
#   ('dis product', 0.425),
#   ('product work', 0.3832)],
#  [('need stock', 0.6138)],
#  [('good product', 1.0)],
#  [('record electric violin', 0.6652),
#   ('violin direct laptopthere', 0.6472),
#   ('able record electric', 0.5634),
#   ('background noise edit', 0.5395),
#   ('electric violin direct', 0.5244)],
#  [('cheap nice', 0.9253)],
#  [('systems sounds cards', 0.7527),
#   ('sounds cards slots', 0.7416),
#   ('extension systems sounds', 0.6474),
#   ('sounds cards', 0.6383),
#   ('systems sounds', 0.5287)],
#  [('device attach', 0.5294),
#   ('reads device attach', 0.4814),
#   ('device attach simply', 0.478),
#   ('computer reads device', 0.4603),
#   ('reads device', 0.4521)],
#  [('driver available', 0.8581)],
#  [],
#  [('usb hub dac', 0.6287),
#   ('usb hub', 0.5195),
#   ('wow usb hub', 0.5028),
#   ('basic usb equipments', 0.4988),
#   ('usb equipments', 0.4946)],
#  [('awesome product value', 0.8872),
#   ('product value money', 0.6366),
#   ('awesome product', 0.6103),
#   ('value money', 0.5601),
#   ('product value', 0.5127)],
#  [],
#  [('issues sound quality', 0.654),
#   ('sound quality absolutely', 0.6415),
#   ('sound quality', 0.6052),
#   ('issues sound', 0.5295),
#   ('quality absolutely', 0.4875)],
#  [('value money', 0.9327)],
#  [('product delivered fast', 0.6244),
#   ('fast quality sound', 0.5585),
#   ('delivered fast quality', 0.5515),
#   ('helpful sound port', 0.5049),
#   ('fast quality', 0.4648)],
#  [('read usb', 0.5844),
#   ('usb time china', 0.5697),
#   ('fails read usb', 0.5211),
#   ('read usb time', 0.5093),
#   ('usb time', 0.4836)],
#  [('monet qualitiy product', 0.6399),
#   ('value monet qualitiy', 0.6065),
#   ('product feature ata', 0.5584),
#   ('value monet', 0.5562),
#   ('qualitiy product feature', 0.5538)],
#  [('working good quality', 0.8639),
#   ('working good', 0.7423),
#   ('quality good', 0.7174),
#   ('good quality good', 0.6734),
#   ('good quality', 0.6251)],
#  [('driver package', 0.7528),
#   ('driver package search', 0.6562),
#   ('windows update', 0.3303),
#   ('manually windows update', 0.2556),
#   ('manually windows', 0.1828)],
#  [('laptop recording', 0.6889),
#   ('connected laptop recording', 0.6548),
#   ('background connected laptop', 0.4722),
#   ('works high pitched', 0.4448),
#   ('high pitched noice', 0.4112)],
#  [('build quality sound', 0.6367),
#   ('build quality', 0.635),
#   ('quality sound quality', 0.5957),
#   ('sound quality looks', 0.5736),
#   ('quality sound', 0.5611)],
#  [('usb ports', 0.4792),
#   ('board usb ports', 0.4754),
#   ('extension audio', 0.4522),
#   ('board usb', 0.444),
#   ('nano board usb', 0.4199)],
#  [('quality good price', 0.9214),
#   ('quality good', 0.7937),
#   ('good quality good', 0.7486),
#   ('good quality', 0.7347),
#   ('good price', 0.5533)],
#  [('high quality sound', 0.7473),
#   ('quality sound', 0.7074),
#   ('product high quality', 0.6028),
#   ('high quality', 0.5776),
#   ('nice product high', 0.5168)],
#  [('good sound quality', 1.0),
#   ('sound quality', 0.9035),
#   ('good sound', 0.7477)],
#  [('usb ports extension', 0.5703),
#   ('mic usb ports', 0.5458),
#   ('sound card separate', 0.5356),
#   ('sound card', 0.5301),
#   ('mic usb', 0.5244)],
#  [('secro audio usb', 0.6634),
#   ('secro audio hub', 0.6458),
#   ('audio usb hub', 0.6238),
#   ('hub motherboard audio', 0.618),
#   ('usb hub motherboard', 0.6085)],
#  [('stopped working 10', 0.776),
#   ('stopped working', 0.7603),
#   ('working 10 days', 0.5867),
#   ('10 days', 0.497),
#   ('working 10', 0.3319)],
#  [('sound card time', 0.5489),
#   ('received secro usb', 0.5194),
#   ('audio sound card', 0.5058),
#   ('sound card', 0.4976),
#   ('usb hub audio', 0.4647)],
#  [],
#  [('headphone jack laptops', 0.831),
#   ('defective headphone jack', 0.7177),
#   ('defective headphone', 0.6635),
#   ('jack laptops', 0.6616),
#   ('jack laptops definitely', 0.6613)],
#  [('good combination works', 0.8388),
#   ('good combination', 0.7411),
#   ('combination works fine', 0.7315),
#   ('combination works', 0.6775),
#   ('works fine', 0.4894)],
#  [('cpu usb ports', 0.6665),
#   ('cpu usb', 0.645),
#   ('usb cpu', 0.6324),
#   ('usb cpu usb', 0.6092),
#   ('plugin usb cpu', 0.6057)],
#  [('audio quality good', 0.8556),
#   ('audio quality', 0.849),
#   ('quality good', 0.5149)],
#  [('external adapters really', 0.6149),
#   ('external adapters', 0.5603),
#   ('tried external adapters', 0.5194),
#   ('adapters really low', 0.5015),
#   ('adapters really', 0.49)],
#  [('product recently working', 0.5503),
#   ('working expected', 0.435),
#   ('recently working expected', 0.4263),
#   ('purchased product recently', 0.3811),
#   ('product recently', 0.3185)],
#  [('purpose adapter wire', 0.7853),
#   ('adapter wire good', 0.7141),
#   ('purpose adapter', 0.6615),
#   ('serves purpose adapter', 0.6596),
#   ('adapter wire', 0.5676)],
#  [('value money', 0.9327)],
#  [('complain price', 0.7118)],
#  [('good product value', 0.8538),
#   ('product value money', 0.723),
#   ('value money', 0.6668),
#   ('good product', 0.6265),
#   ('product value', 0.6058)],
#  [('best affordable 10', 0.8999),
#   ('affordable 10 10', 0.8561),
#   ('affordable 10', 0.8244),
#   ('best affordable', 0.6999),
#   ('10 10', 0.4397)],
#  [('device sound quality', 0.7441),
#   ('sound quality good', 0.7168),
#   ('sound quality', 0.6997),
#   ('extarnal sound device', 0.678),
#   ('best extarnal sound', 0.6645)],
#  [],
#  [('product vest money', 0.8481),
#   ('product vest', 0.8248),
#   ('vest money', 0.7426)],
#  [('product connected midi', 0.6408),
#   ('connected midi', 0.6199),
#   ('connected midi keyboard', 0.6046),
#   ('midi keyboard monitor', 0.5925),
#   ('audio product connected', 0.57)],
#  [('300 best sound', 0.6669),
#   ('best sound card', 0.6442),
#   ('sound card build', 0.6073),
#   ('sound card', 0.568),
#   ('card build quality', 0.4759)],
#  [('qualityand usb hub', 0.7349),
#   ('audio qualityand usb', 0.7009),
#   ('clear audio qualityand', 0.6334),
#   ('audio quality great', 0.6186),
#   ('crystal clear audio', 0.617)],
#  [],
#  [('good small compact', 0.7295),
#   ('compact good quality', 0.719),
#   ('small compact good', 0.7058),
#   ('compact good', 0.5788),
#   ('small compact', 0.5547)]]

# %%
from collections import defaultdict

counts = defaultdict(int)

for kps in keyphrases:
  for kp in kps:
    phrase = kp[0]
    counts[phrase] = counts[phrase] + 1

# %%
counts.keys()
# Out:
# dict_keys(['good earphones connection', 'earphones connection', 'earphones connection working', 'good earphones', 'connection working correctly', 'kharab ho gaya', 'jaldi kharab ho', 'jaldi kharab', 'kharab ho', 'ho gaya', 'product stopped working', 'product stopped', 'month product stopped', 'stopped working', 'replace return product', 'sound quality', 'sound quality just', 'great use earphones', 'earphones headphones', 'use earphones', 'long cable usb', 'nice long cable', 'long cable', 'cable usb', 'cable usb ports', 'dislike free aslo', 'free aslo', 'super dislike free', 'dislike free', 'super dislike', 'better dac laptop', 'dac laptop', 'dac laptop major', 'better dac', 'laptop usb port', 'usb port working', 'bad sound port', 'usb working', 'audio port working', 'working usb port', 'stream recording purpose', 'stream recording', 'recommend stream recording', 'mic single channel', 'stereo mic', 'stops working', 'stops working hrsgiv', 'working stops', 'working stops hrs', 'start working stops', 'waste money', 'nice sound', 'audio jack need', 'combiner audio jack', 'audio jack', 'adapters audio jack', 'device adapters audio', 'product great cable', 'haven tested mic', 'tested mic headphone', 'mic headphone port', 'mic headphone', 'percent loud microphone', 'loud microphone', 'loud microphone does', 'microphone does work', 'gives volume', 'connecting minute disconnecting', 'use device troubleshooting', 'disconnecting use device', 'working properly connecting', 'properly connecting', 'good product', 'crap cheap material', 'disconnected high brand', 'complete crap cheap', 'gets disconnected', 'crap cheap', 'increases loudnessand audio', 'dosent improve sound', 'increases loudnessand', 'sound increases loudnessand', 'improve sound increases', 'said product unreturnable', 'return said product', 'product unreturnable', 'product unreturnable send', 'unreturnable send money', 'usb audio card', 'voice breaks', 'replaced voice breaks', 'audio card', 'usb audio', 'product hot easily', 'product hot', 'disconnects calls gaming', 'hot easily', 'calls gaming', 'using hangingsound breaking', 'hangingsound breaking', 'hour using hangingsound', 'using hangingsound', 'hour using', 'product looking forworth', 'looking forworth buy', 'forworth buy', 'looking forworth', 'perfect product looking', 'mention sound quality', 'sound quality sheerness', 'quality sheerness value', 'mention sound', 'drop connection', 'month drop connection', 'drop connection frequently', 'connection frequently working', 'connection frequently', 'phone usb cable', 'phone usb', 'accept phone usb', 'helpful usb does', 'usb cable', 'noise problem pa', 'facing noise problem', 'recommend facing noise', 'noise problem', 'facing noise', 'th stoped working', 'stoped working dont', 'working dont buy', 'stoped working', '1st working', 'quality bad product', 'used product bad', 'product quality bad', 'product comes dust', 'product quality', 'product good usb', 'ps4 good quality', 'pc ps4 good', 'good usb cable', 'ps4 good', 'excellent product price', 'price little high', 'product price little', 'price little', 'excellent product', 'worst product failed', 'sorting mother board', 'worst product', 'mother board', 'product failed', 'stopped working days', 'days waste money', 'days waste', 'product working', 'good quality', 'mouse combo usb', 'combo usb', 'connect mouse keyboard', 'laptop keyboards', 'combo usb able', 'awesomesolved usb aux', 'usb aux ports', 'aux ports problem', 'usb aux', 'audio cards', 'product headphone port', 'cheap audio cards', 'headphone port', 'headphone port working', 'usb port parallel', 'multiple usb port', 'use multiple usb', 'multiple usb', 'mac mixer', 'sound mixer mac', 'mixer mac', 'live streaming purpose', 'mac mixer works', 'sound card external', 'audio sound card', 'card external headphone', 'sound card', 'yes best audio', 'overall good', 'overall good kind', 'good kind price', 'kind price', 'good kind', 'sound disturbing', 'bm 800 microphonei', 'micr ...

# %%
sorted(list(counts.items()))
# Out:
# [('10 10', 1),
#  ('10 days', 1),
#  ('1st working', 1),
#  ('2nd 3rd usb', 1),
#  ('300 best sound', 1),
#  ('3rd usb', 1),
#  ('3rd usb port', 1),
#  ('800 microphonei recommend', 1),
#  ('able record electric', 1),
#  ('accept phone usb', 1),
#  ('adapter wire', 1),
#  ('adapter wire good', 1),
#  ('adapters audio jack', 1),
#  ('adapters really', 1),
#  ('adapters really low', 1),
#  ('affordable 10', 1),
#  ('affordable 10 10', 1),
#  ('asked refund', 1),
#  ('audacity otg connect', 1),
#  ('audio adapter', 1),
#  ('audio card', 1),
#  ('audio cards', 1),
#  ('audio distance', 1),
#  ('audio jack', 1),
#  ('audio jack need', 1),
#  ('audio listening', 1),
#  ('audio listening use', 1),
#  ('audio port working', 2),
#  ('audio product connected', 1),
#  ('audio quality', 2),
#  ('audio quality good', 1),
#  ('audio quality great', 1),
#  ('audio quality really', 1),
#  ('audio qualityand usb', 1),
#  ('audio sound card', 2),
#  ('audio usb hub', 1),
#  ('auto installation', 1),
#  ('auto installation usb', 1),
#  ('aux ports problem', 1),
#  ('awesome product', 1),
#  ('awesome product value', 1),
#  ('awesomesolved usb aux', 1),
#  ('background connected laptop', 1),
#  ('background noise edit', 1),
#  ('bad noise', 1),
#  ('bad sound port', 1),
#  ('basic usb equipments', 1),
#  ('best affordable', 1),
#  ('best affordable 10', 1),
#  ('best extarnal sound', 1),
#  ('best sound card', 1),
#  ('better dac', 1),
#  ('better dac laptop', 1),
#  ('bm 800 microphonei', 1),
#  ('board usb', 1),
#  ('board usb ports', 1),
#  ('brand usb audio', 1),
#  ('build quality', 2),
#  ('build quality mark', 1),
#  ('build quality sound', 1),
#  ('built quality', 1),
#  ('buying output', 1),
#  ('buying output lot', 1),
#  ('cable provided', 1),
#  ('cable usb', 1),
#  ('cable usb ports', 1),
#  ('calls gaming', 1),
#  ('came working properly', 1),
#  ('card build quality', 1),
#  ('card external headphone', 1),
#  ('cheap audio cards', 1),
#  ('cheap nice', 1),
#  ('cheap product', 1),
#  ('clear audio qualityand', 1),
#  ('combination works', 1),
#  ('combination works fine', 1),
#  ('combiner audio jack', 1),
#  ('combo usb', 1),
#  ('combo usb able', 1),
#  ('compact good', 1),
#  ('compact good quality', 1),
#  ('complain price', 1),
#  ('complete crap cheap', 1),
#  ('computer reads device', 1),
#  ('connect mouse keyboard', 1),
#  ('connected laptop recording', 1),
#  ('connected midi', 1),
#  ('connected midi keyboard', 1),
#  ('connecting minute disconnecting', 1),
#  ('connection frequently', 1),
#  ('connection frequently working', 1),
#  ('connection working correctly', 1),
#  ('cpu usb', 1),
#  ('cpu usb ports', 1),
#  ('crap cheap', 1),
#  ('crap cheap material', 1),
#  ('crystal clear audio', 1),
#  ('dac laptop', 1),
#  ('dac laptop major', 1),
#  ('daw using midi', 1),
#  ('days waste', 1),
#  ('days waste money', 1),
#  ('defective headphone', 1),
#  ('defective headphone jack', 1),
#  ('delivered fast quality', 1),
#  ('designed build', 1),
#  ('designed build quality', 1),
#  ('detected laptop', 1),
#  ('detected laptop connected', 1),
#  ('device adapters audio', 1),
#  ('device attach', 1),
#  ('device attach simply', 1),
#  ('device sound quality', 1),
#  ('digital piano', 1),
#  ('digital piano suggest', 1),
#  ('digital sound local', 1),
#  ('dis product', 1),
#  ('dis product work', 1),
#  ('disconnected high brand', 1),
#  ('disconnecting use device', 1),
#  ('disconnects calls gaming', 1),
#  ('dislike free', 1),
#  ('dislike free aslo', 1),
#  ('distance audio', 1),
#  ('disturbing computer', 1),
#  ('doesn work', 1),
#  ('don buy', 1),
#  ('dosent improve sound', 1),
#  ('driver available', 1),
#  ('driver package', 1),
#  ('driver package search', 1),
#  ('drop connection', 1),
#  ('drop connection frequently', 1),
#  ('earphone use', 1),
#  ('earphone use usb', 1),
#  ('earphones connection', 1),
#  ('earphones connection working', 1),
#  ('earphones headphones', 1),
#  ('easy auto installation', 1),
#  ('easy use', 1),
#  ('easy use issue', 1),
#  ('electric violin direct', 1),
#  ('excellent product', 1),
#  ('excellent product price', 1),
#  ('extarnal sound device', 1),
#  ('extension audio', 1),
#  ('extension systems sounds', 1),
#  ('external adapters', 1),
#  ('external adapters really', 1),
#  ('extra usb ports', 1),
#  ('facing noise', 1),
#  ('facing noise problem', 1),
#  ('fails read usb', 1),
#  ('fast quality', 1),
#  ('fast quality sound', 1),
#  ('forworth buy', 1),
#  ('free aslo', 1),
#  ('free performance microphone', 1),
#  ('gets disconnected', 1),
#  ('gives volume', 1),
#  ('good audio listening', 1),
#  ('good combination', 1),
#  ('good combination works', 1),
#  ('good earphones', 1),
#  ('good earphones connection', 1),
#  ('good kind', 1),
#  ('good kind price', 1),
#  ('good microphone volume', 1),
#  ('good price', 1),
#  ('good product', 3),
#  ('good product value', 1),
#  ('good quality', 3),
#  ('good quality good', 2),
#  ('good quality ontime', 1),
#  ('good small compact', 1),
#  ('good sound', 2),
#  ('good sound quality', 2),
#  ('good usb', 1),
#  ('good usb cable', 1),
#  ('good usb port', 1),
#  ('goodpendrive working', 1),
#  ('got issue cable', 1),
#  ('great use earphones', 1),
#  ('hangingsound breaking', 1),
#  ('haven tested mic', 1),
#  ('headphone jack laptops', 1),
#  ('headphone jack mouse', 1),
#  ('headphone port', 1),
#  ('headphone port working', 1),
#  ('headset works', 1),
#  ('headset works speakers', 1),
#  ('helpful sound port', 1),
#  ('helpful usb does', 1),
#  ('high pitched noice', 1),
#  ('high quality', 1),
#  ('high quality sound', 1),
#  ('ho gaya', 1),
#  ('hot easily', 1),
#  ('hour using', 1),
#  ('hour using hangingsound', 1),
#  ('hub motherboard audio', 1),
#  ('hub recieved', 1),
#  ('hub recieved wire', 1),
#  ('improve sound increases', 1),
#  ('increases loudnessand', 1),
#  ('increases loudnessand audio', 1),
#  ('input audio distance', 1),
#  ('input doesn', 1),
#  ('input doesn work', 1),
#  ('installation usb', 1),
#  ('installation usb audio', 1),
#  ('issue cable', 1),
#  ('issue cable provided', 1),
#  ('issues sound', 1),
#  ('issues sound quality', 1),
#  ('jack laptops', 1),
#  ('jack laptops definitely', 1),
#  ('jack mouse keyboard', 1),
#  ('jaldi kharab', 1),
#  ('jaldi kharab ho', 1),
#  ('just useless', 1),
#  ('just useless don', 1),
#  ('kharab ho', 1),
#  ('kharab ho gaya', 1),
#  ('kind price', 1),
#  ('laptop audio', 1),
#  ('laptop connected', 1),
#  ('laptop connected worked', 1),
#  ('laptop keyboards', 1),
#  ('laptop recording', 1),
#  ('laptop usb port', 1),
#  ('listening use plug', 1),
#  ('live streaming purpose', 1),
#  ('local sound', 1),
#  ('local sound street', 1),
#  ('long cable', 1),
#  ('long cable usb', 1),
#  ('looking forworth', 1),
#  ('looking forworth buy', 1),
#  ('loud microphone', 1),
#  ('loud microphone does', 1),
#  ('mac mixer', 1),
#  ('mac mixer works', 1),
#  ('makes bad', 1),
#  ('makes bad noise', 1),
#  ('manually windows', 1),
#  ('manually windows update', 1),
#  ('mention sound', 1),
#  ('mention sound quality', 1),
#  ('mic headphone', 1),
#  ('mic headphone port', 1),
#  ('mic input', 1),
#  ('mic input doesn', 1),
#  ('mic single channel', 1),
#  ('mic usb', 1),
#  ('mic usb ports', 1),
#  ('microphone does work', 1),
#  ('microphone listen', 1),
#  ('microphone low', 1),
#  ('microphone volume', 1),
#  ('microphone volume low', 1),
#  ('microphonei recommend bm', 1),
#  ('midi keyboard monitor', 1),
#  ('mixer mac', 1),
#  ('monet qualitiy product', 1),
#  ('money laptop audio', 1),
#  ('month drop connection', 1),
#  ('month product stopped', 1),
#  ('mother board', 1),
#  ('mouse combo usb', 1),
#  ('mouse keyboard', 1),
#  ('multiple usb', 1),
#  ('multiple usb port', 1),
#  ('nano board usb', 1),
#  ('necessarily disconnect reconnect', 1),
#  ('need stock', 1),
#  ('nice long cable', 1),
#  ('nice product high', 1),
#  ('nice productvery', 1),
#  ('nice productvery super', 1),
#  ('nice quality', 1),
#  ('nice quality product', 1),
#  ('nice sound', 1),
#  ('nice working good', 1),
#  ('nit detected laptop', 1),
#  ('noise free performance', 1),
#  ('noise problem', 1),
#  ('noise problem pa', 1),
#  ('ontime delivery', 1),
#  ('original cover', 1),
#  ('output lot disturbance', 1),
#  ('overall good', 1),
#  ('overall good kind', 1),
#  ('pc ps4 good', 1),
#  ('pc speaker', 1),
#  ('pc speaker makes', 1),
#  ('pendrive speaker cable', 1),
#  ('percent loud microphone', 1),
#  ('perfect product looking', 1),
#  ('performance microphone', 1),
#  ('performance microphone low', 1),
#  ('phone usb', 1),
#  ('phone usb cable', 1),
#  ('piano output really', 1),
#  ('plugin usb cpu', 1),
#  ('port work', 1),
#  ('price getting usb', 1),
#  ('price little', 1),
#  ('price little high', 1),
#  ('problem audio', 1),
#  ('problem audio adapter', 1),
#  ('problem using', 1),
#  ('problem using month', 1),
#  ('problems asked refund', 1),
#  ('product comes dust', 1),
#  ('product connected midi', 1),
#  ('product delivered fast', 1),
#  ('product easy', 1),
#  ('product easy use', 1),
#  ('product failed', 1),
#  ('product feature ata', 1),
#  ('product good audio', 1),
#  ('product good usb', 1),
#  ('product great cable', 1),
#  ('product headphone port', 1),
#  ('product high quality', 1),
#  ('product hot', 1),
#  ('product hot easily', 1),
#  ('product issues', 1),
#  ('product looking forworth', 1),
#  ('product price little', 1),
#  ('product quality', 1),
#  ('product quality bad', 1),
#  ('product recently', 1),
#  ('product recently working', 1),
#  ('product stopped', 1),
#  ('product stopped working', 1),
#  ('product unreturnable', 1),
#  ('product unreturnable send', 1),
#  ('product value', 2),
#  ('product value money', 2),
#  ('product vest', 1),
#  ('product vest money', 1),
#  ('product work', 1),
#  ('product work nic', 1),
#  ('product working', 3),
#  ('product working properlythis', 1),
#  ('productvery super', 1),
#  ('productvery super duper', 1),
#  ('properly connecting', 1),
#  ('properly used cable', 1),
#  ('properlythis experience disappointing', 1),
#  ('ps4 good', 1),
#  ('ps4 good quality', 1),
#  ('ps4 supports', 1),
#  ('ps4 supports quite', 1),
#  ('purchased product recently', 1),
#  ('purpose adapter', 1),
#  ('purpose adapter wire', 1),
#  ('qualitiy product feature', 1),
#  ('quality absolutely', 1),
#  ('quality bad product', 1),
#  ('quality good', 3),
#  ('quality good price', 1),
#  ('quality ontime delivery', 1),
#  ('quality product', 1),
#  ('quality product issues', 1),
#  ('quality sheerness value', 1),
#  ('quality sound', 2),
#  ('quality sound quality', 1),
#  ('quality use microphone', 1),
#  ('qualityand usb hub', 1),
#  ('read usb', 1),
#  ('read usb time', 1),
#  ('reads device', 1),
#  ('reads device attach', 1),
#  ('receive usb hub', 1),
#  ('received secro usb', 1),
#  ('recently working expected', 1),
#  ('recommend facing noise', 1),
#  ('recommend stream recording', 1),
#  ('reconnect connection stable', 1),
#  ('record electric violin', 1),
#  ('refund don original', 1),
#  ('replace return product', 1),
#  ('replaced voice breaks', 1),
#  ('return said product', 1),
#  ('returned product', 1),
#  ('returned product working', 1),
#  ('said product unreturnable', 1),
#  ('screen lock standby', 1),
#  ('screen unlock works', 1),
#  ('secro audio hub', 1),
#  ('secro audio usb', 1),
#  ('serves purpose adapter', 1),
#  ('small compact', 1),
#  ('small compact good', 1),
#  ('sorting mother board', 1),
#  ('sound card', 5),
#  ('sound card build', 1),
#  ('sound card external', 1),
#  ('sound card separate', 1),
#  ('sound card time', 1),
#  ('sound digital piano', 1),
#  ('sound disturbing', 1),
#  ('sound increases loudnessand', 1),
#  ('sound microphone', 1),
#  ('sound microphone thanks', 1),
#  ('sound mixer mac', 1),
#  ('sound quality', 8),
#  ('sound quality absolutely', 1),
#  ('sound quality good', 2),
#  ('sound quality just', 1),
#  ('sound quality looks', 1),
#  ('sound quality sheerness', 1),
#  ('sound street', 1),
#  ('sound street players', 1),
#  ('soundbut work', 1),
#  ('soundbut work cubase', 1),
#  ('sounds cards', 1),
#  ('sounds cards slots', 1),
#  ('standby necessarily disconnect', 1),
#  ('starmaker singsuperb', 1),
#  ('start working stops', 1),
#  ('starting pc speaker', 1),
#  ('stereo mic', 1),
#  ('stoped working', 1),
#  ('stoped working dont', 1),
#  ('stopped working', 3),
#  ('stopped working 10', 1),
#  ('stopped working days', 1),
#  ('stops working', 1),
#  ('stops working hrsgiv', 1),
#  ('stream recording', 1),
#  ('stream recording purpose', 1),
#  ('super dislike', 1),
#  ('super dislike free', 1),
#  ('super duper', 1),
#  ('supports quite sturdy', 1),
#  ('systems sounds', 1),
#  ('systems sounds cards', 1),
#  ('tested mic headphone', 1),
#  ('th stoped working', 1),
#  ('tried external adapters', 1),
#  ('unreturnable send money', 1),
#  ('usb audio', 2),
#  ('usb audio card', 1),
#  ('usb audio utterly', 1),
#  ('usb aux', 1),
#  ('usb aux ports', 1),
#  ('usb cable', 1),
#  ('usb cable hp', 1),
#  ('usb came', 1),
#  ('usb came working', 1),
#  ('usb cpu', 1),
#  ('usb cpu usb', 1),
#  ('usb equipments', 1),
#  ('usb headphone', 1),
#  ('usb hub', 3),
#  ('usb hub audio', 1),
#  ('usb hub dac', 1),
#  ('usb hub motherboard', 1),
#  ('usb hub recieved', 1),
#  ('usb hub sound', 1),
#  ('usb port', 2),
#  ('usb port detecting', 1),
#  ('usb port parallel', 1),
#  ('usb port usb', 1),
#  ('usb port work', 1),
#  ('usb port working', 1),
#  ('usb port works', 1),
#  ('usb ports', 2),
#  ('usb ports extension', 1),
#  ('usb slots', 1),
#  ('usb slots simultaneously', 1),
#  ('usb sound card', 1),
#  ('usb time', 1),
#  ('usb time china', 1),
#  ('usb working', 1),
#  ('use device troubleshooting', 1),
#  ('use earphones', 1),
#  ('use multiple usb', 1),
#  ('use usb slots', 1),
#  ('used cable', 1),
#  ('used product bad', 1),
#  ('used ps4 supports', 1),
#  ('useful used ps4', 1),
#  ('useless don', 1),
#  ('useless don buy', 1),
#  ('using hangingsound', 1),
#  ('using hangingsound breaking', 1),
#  ('using month', 1),
#  ('value monet', 1),
#  ('value monet qualitiy', 1),
#  ('value money', 4),
#  ('value money got', 1),
#  ('vest money', 1),
#  ('violin direct laptopthere', 1),
#  ('vocals recording works', 1),
#  ('voice breaks', 1),
#  ('wanted sound microphone', 1),
#  ('waste money', 2),
#  ('way designed build', 1),
#  ('windows update', 1),
#  ('wire cpu', 1),
#  ('work nic', 1),
#  ('working 10', 1),
#  ('working 10 days', 1),
#  ('working dont buy', 1),
#  ('working expected', 1),
#  ('working good', 1),
#  ('working good quality', 2),
#  ('working good usb', 1),
#  ('working properly connecting', 1),
#  ('working properlythis', 1),
#  ('working properlythis experience', 1),
#  ('working stops', 1),
#  ('working stops hrs', 1),
#  ('working usb port', 1),
#  ('works bm 800', 1),
#  ('works fine', 1),
#  ('works fine usb', 1),
#  ('works high pitched', 1),
#  ('works speakers', 1),
#  ('works starmaker singsuperb', 1),
#  ('worst built', 1),
#  ('worst built quality', 1),
#  ('worst product', 2),
#  ('worst product failed', 1),
#  ('worth buying', 1),
#  ('worth buying output', 1),
#  ('wow usb hub', 1),
#  ('yes best audio', 1)]

# %% [markdown]
# # filter results

# %%
[nltk.pos_tag(word_tokenize(tag)) for tag in list(tags)]
# Out:
# [[('printer', 'NN'), ('cable', 'NN')],
#  [('sound', 'JJ'), ('quality', 'NN')],
#  [('usb', 'JJ'), ('hub', 'NN')],
#  [('dont', 'NN'), ('buy', 'NN')],
#  [('build', 'NN'), ('quality', 'NN')],
#  [('working', 'VBG'), ('fine', 'NN')],
#  [('value', 'NN'), ('for', 'IN'), ('money', 'NN')],
#  [('waste', 'NN'), ('of', 'IN'), ('money', 'NN')],
#  [('good', 'JJ'), ('quality', 'NN')],
#  [('hard', 'JJ'), ('drive', 'NN')],
#  [('usb', 'JJ'), ('port', 'NN')],
#  [('worth', 'JJ'), ('buying', 'NN')],
#  [('sound', 'JJ'), ('card', 'NN')],
#  [('audio', 'JJ'), ('quality', 'NN')],
#  [('stopped', 'VBD'), ('working', 'VBG')],
#  [('recommend', 'NN'), ('not', 'RB'), ('to', 'TO'), ('buy', 'VB')],
#  [('audio', 'JJ'), ('jack', 'NN')],
#  [('works', 'NNS'), ('well', 'RB')],
#  [('keeps', 'NNS'), ('disconnecting', 'VBG')],
#  [('working', 'VBG'), ('properly', 'RB')]]

# %%
def good_pos_comb(tokens):
  good_pos = [
    # ['NN', 'NN'],
    # ['NN', 'IN', 'NN'],
    ['JJ', 'NN'],
    ['VBD', 'VBG'],
    # ['NNS', 'RB'],
    # ['NNS', 'VBG'],
    # ['VBG', 'RB'],
  ]
  pos = [token[1] for token in tokens]
  return pos in good_pos

# [k for k in vectorizer.vocabulary_.keys() if good_pos_comb(nltk.pos_tag(word_tokenize(k)))]


[k for k in counts.keys() if good_pos_comb(nltk.pos_tag(word_tokenize(k)))]

# NN IN NN
# NN NN
# JJ NN
# VBD VBG
# NNS RB
# NNS VBG
# VBG RB
# Out:
# ['stopped working',
#  'sound quality',
#  'free aslo',
#  'nice sound',
#  'audio jack',
#  'mic headphone',
#  'loud microphone',
#  'good product',
#  'audio card',
#  'usb audio',
#  'usb cable',
#  'stoped working',
#  'excellent product',
#  'good quality',
#  'usb aux',
#  'multiple usb',
#  'sound card',
#  'good kind',
#  'usb headphone',
#  'mic input',
#  'laptop audio',
#  'usb hub',
#  'nice quality',
#  'audio quality',
#  'nice productvery',
#  'super duper',
#  'useless don',
#  'usb port',
#  'bad noise',
#  'good usb',
#  'easy use',
#  'goodpendrive working',
#  'audio distance',
#  'original cover',
#  'worth buying',
#  'good sound',
#  'cheap product',
#  'sound street',
#  'local sound',
#  'digital piano',
#  'dis product',
#  'cheap nice',
#  'awesome product',
#  'usb time',
#  'laptop recording',
#  'good price',
#  'high quality',
#  'mic usb',
#  'defective headphone',
#  'good combination',
#  'usb cpu',
#  'small compact']

# %% [markdown]
# # keyword extraction

# %% [markdown]
# # Ideas
#
# * can you phrase that as muliple question answering problem?
#
# * summarization + question answering
